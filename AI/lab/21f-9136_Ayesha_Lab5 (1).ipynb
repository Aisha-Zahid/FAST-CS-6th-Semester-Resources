# %%
def bfs(graph, start_node, goal_node):
    queue = [start_node]
    visited = set()
    shortest_path = []

    while queue:
        current_node = queue.pop(0)
        if current_node not in visited:
            visited.add(current_node)
            shortest_path.append(current_node)
            if current_node == goal_node:
                return shortest_path
            for neighbor_node in graph[current_node]:
                if neighbor_node not in visited:
                    queue.append(neighbor_node)

    return None

# %%
graph = { "A" : ["B", "E", "C"],
"B" : ["E","D"],
"C" : ["F","G"],
"D" : ["B","E"],
"E" : ["A","B","D"],
"F" : ["C"],
"G" : ["C"] }

def dfs(graph, start, goal):
    stack = [start]
    visited = set()
    sequence = []

    while stack:
        node = stack.pop()
        if node not in visited:
            visited.add(node)
            sequence.append(node)
            if node == goal:
                return sequence
            for neighbor in graph[node]:
                if neighbor not in visited:
                    stack.append(neighbor)

    return None

dfs(graph,"A","F")
# Out:
# ['A', 'C', 'G', 'F']

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 23
#       1 nodes_and_edges = {
#       2     'Arad': ['Zerind', 'Sibiu', 'Timisoara'],
#       3     'Zerind': ['Oradea', 'Arad'],
#    (...)
#      20     'Neamt': ['Lasi']
#      21 }
# ---> 23 print(bfs(nodes_and_edges, 'Arad', 'Bucharest'))
#
# Cell In[9], line 13, in bfs(nodes_and_edges, start, goal)
#      11 if node == goal:
#      12     return path
# ---> 13 for neighbor in nodes_and_edges[node]:
#      14     if neighbor not in visited:
#      15         queue.append(neighbor)
#
# KeyError: 'Sibiu'

# %%
graph = {
    'Arad': {'Zerind': 75, 'Sibiu': 140, 'Timisoara': 118},
    'Zerind': {'Oradea': 71, 'Arad': 75},
    'Oradea': {'Zerind': 71, 'Sibiu': 151, 'Napoca': 138},
    'Timisoara': {'Arad': 118, 'Lugoj': 111},
    'Lugoj': {'Timisoara': 111, 'Mehadia': 70, 'Caransebes': 118},
    'Mehadia': {'Lugoj': 70, 'Drobeta': 120, 'Sibiu': 99},
    'Drobeta': {'Mehadia': 120, 'Craiova': 138},
    'Craiova': {'Drobeta': 138, 'Rimnicu Vilcea': 146, 'Pitesti': 138},
    'Rimnicu Vilcea': {'Craiova': 146, 'Pitesti': 97, 'Fagaras': 80},
    'Fagaras': {'Rimnicu Vilcea': 80, 'Bucharest': 99},
    'Pitesti': {'Rimnicu Vilcea': 97, 'Craiova': 138, 'Bucharest': 211},
    'Bucharest': {'Fagaras': 99, 'Pitesti': 211, 'Giurgiu': 90, 'Urziceni': 85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Hirsova': 98, 'Vaslui': 92},
    'Hirsova': {'Urziceni': 98, 'Eforie': 86},
    'Eforie': {'Hirsova': 86},
    'Vaslui': {'Urziceni': 92, 'Lasi': 142, 'Iasi': 92},
    'Lasi': {'Vaslui': 142, 'Neamt': 87},
    'Neamt': {'Lasi': 87}
}
print(graph)
# Out:
# {'Arad': {'Zerind': 75, 'Sibiu': 140, 'Timisoara': 118}, 'Zerind': {'Oradea': 71, 'Arad': 75}, 'Oradea': {'Zerind': 71, 'Sibiu': 151, 'Napoca': 138}, 'Timisoara': {'Arad': 118, 'Lugoj': 111}, 'Lugoj': {'Timisoara': 111, 'Mehadia': 70, 'Caransebes': 118}, 'Mehadia': {'Lugoj': 70, 'Drobeta': 120, 'Sibiu': 99}, 'Drobeta': {'Mehadia': 120, 'Craiova': 138}, 'Craiova': {'Drobeta': 138, 'Rimnicu Vilcea': 146, 'Pitesti': 138}, 'Rimnicu Vilcea': {'Craiova': 146, 'Pitesti': 97, 'Fagaras': 80}, 'Fagaras': {'Rimnicu Vilcea': 80, 'Bucharest': 99}, 'Pitesti': {'Rimnicu Vilcea': 97, 'Craiova': 138, 'Bucharest': 211}, 'Bucharest': {'Fagaras': 99, 'Pitesti': 211, 'Giurgiu': 90, 'Urziceni': 85}, 'Giurgiu': {'Bucharest': 90}, 'Urziceni': {'Bucharest': 85, 'Hirsova': 98, 'Vaslui': 92}, 'Hirsova': {'Urziceni': 98, 'Eforie': 86}, 'Eforie': {'Hirsova': 86}, 'Vaslui': {'Urziceni': 92, 'Lasi': 142, 'Iasi': 92}, 'Lasi': {'Vaslui': 142, 'Neamt': 87}, 'Neamt': {'Lasi': 87}}

# %%
graph = {
    'Sibiu': ['Fagaras', 'Rimnicu Vilcea', 'Pitesti'],
    'Fagaras': ['Sibiu', 'Bucharest'],
    'Rimnicu Vilcea': ['Sibiu', 'Pitesti', 'Craiova'],
    'Pitesti': ['Rimnicu Vilcea', 'Craiova', 'Bucharest'],
    'Bucharest': ['Fagaras', 'Pitesti', 'Giurgiu', 'Urziceni'],
}

costs = {
    ('Sibiu', 'Fagaras'): 80,
    ('Sibiu', 'Rimnicu Vilcea'): 99,
    ('Sibiu', 'Pitesti'): 101,
    ('Fagaras', 'Bucharest'): 211,
    ('Rimnicu Vilcea', 'Pitesti'): 97,
    ('Rimnicu Vilcea', 'Craiova'): 146,
    ('Pitesti', 'Bucharest'): 211,
    ('Pitesti', 'Craiova'): 138,
}


start = 'Sibiu'
goal = 'Bucharest'
